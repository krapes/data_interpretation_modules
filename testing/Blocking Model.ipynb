# %%
import sys
sys.path.append("..")

from src import MaxmindIp
from helpers import function_time


TOTAL_TIME = 5*60*60
SECTION_TIME = int(TOTAL_TIME / 3)
SEARCH_TIME = int(SECTION_TIME / 4)
print(TOTAL_TIME, SECTION_TIME, SEARCH_TIME)
# Out:
# 18000 6000 1500

# %%
ip = '3.230.115.163'
password = 'i-0f0252857048d9cb8'

# %%
permutations = {'trial_1': {'model_type': 'AutoML', 'cost_matrix_loss_metric': False},
                'trial_2': {'model_type': 'GradientBoosting', 'cost_matrix_loss_metric': False},
                'trial_3': {'model_type': 'GradientBoosting', 'cost_matrix_loss_metric': True}}

# %%
trial = permutations['trial_1']
print(trial)

maxmind = MaxmindIp(ip=ip,
                    username='h2o',
                    password=password,
                    port=54321)
maxmind.config['step'] = 90
maxmind.config['cutoff'] = 85
data = maxmind.train(reset_lookback=False,
                     reset_step=False,
                     sample_size=None,
                     model_type=trial['model_type'],
                     cost_matrix_loss_metric=trial['cost_matrix_loss_metric'],
                     search_time=60*2,
                     evaluate=True)
# Out:
# {'model_type': 'AutoML', 'cost_matrix_loss_metric': False}
# /Users/kerrirapes/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# data available: 14628772
# data length: 14628772
# Checking whether there is an H2O instance running at http://3.230.115.163:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         2 hours 53 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.0.2
# H2O_cluster_version_age:    7 days, 22 hours and 47 minutes
# H2O_cluster_name:           root
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    44.94 Gb
# H2O_cluster_total_cores:    36
# H2O_cluster_allowed_cores:  36
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://3.230.115.163:54321
# H2O_connection_proxy:       null
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  ------------------------------------------------------------------
# Date: 2020-03-31 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.13
# Could not find exact threshold 0.13; using closest threshold found 0.12745223391984667.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.12745223391984667:
#                0      1   Error              Rate
# 0      0  9427.0  264.0  0.0272    (264.0/9691.0)
# 1      1   200.0  109.0  0.6472     (200.0/309.0)
# 2  Total  9627.0  373.0  0.0464   (464.0/10000.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# The modified system has an impact of -1031878.93
# new_approach: -38543630.066666655  -  today: -37511751.13333336
# Date: 2020-06-29 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.13
# Could not find exact threshold 0.13; using closest threshold found 0.1276537785696025.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.1276537785696025:
#                0      1   Error              Rate
# 0      0  9284.0  355.0  0.0368    (355.0/9639.0)
# 1      1   240.0  164.0  0.5941     (240.0/404.0)
# 2  Total  9524.0  519.0  0.0592   (595.0/10043.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# The modified system has an impact of -3011359.57
# new_approach: -42108145.13333327  -  today: -39096785.56666664
# Date: 2020-09-27 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.2
# Could not find exact threshold 0.2; using closest threshold found 0.1936244282753258.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.1936244282753258:
#                0     1   Error              Rate
# 0      0  9622.0  33.0  0.0034     (33.0/9655.0)
# 1      1   348.0  38.0  0.9016     (348.0/386.0)
# 2  Total  9970.0  71.0  0.0379   (381.0/10041.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# The modified system has an impact of 0.0
# new_approach: 0.0  -  today: 0.0
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.2
# Could not find exact threshold 0.2; using closest threshold found 0.1936244282753258.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.1936244282753258:
#                0     1   Error              Rate
# 0      0  9622.0  33.0  0.0034     (33.0/9655.0)
# 1      1   348.0  38.0  0.9016     (348.0/386.0)
# 2  Total  9970.0  71.0  0.0379   (381.0/10041.0)
# <class 'str'>
# /Users/kerrirapes/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/models/StackedEnsemble_AllModels_AutoML_20201125_151745 /Users/kerrirapes/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/models/StackedEnsemble_AllModels_AutoML_20201125_151745

# %%
maxmind.plot_vs_baseline()
# Out:
# Cost Baseline: -76608536.7    Cost New Approach: -80651775.19999994
# Impact: -4043238.4999999404
# <AxesSubplot:xlabel='grp', ylabel='today_result_cost'>

# %%
maxmind.stats_volume_vs_baseline()
# Out:
# Total Volume sent to UPS (TP + FP):
# 	 Baseline: 13877  New Approach: 58222
# The new approach has an increase of 44345 tickets
# This represents an increase of -319.55754125531456 percent

# %%
maxmind.stats_fp_vs_baseline()
# Out:
# Total Fraud Cases Detected (FP):
# 	 Baseline: 5466  New Approach: 54851
# The new approach has an increase of 49385 False Positives
# This represents change of -903.4943285766557 percent

# %%
maxmind.stats_tp_vs_baseline()
# Out:
# Total Fraud Cases Detected (TP):
# 	 Baseline: 8411  New Approach: 3371
# The new approach has a decrease of 5040 True Positives
# This represents change of 59.92153132802282 percent

# %%
volume_based_config = maxmind.configure_volume_equals_baseline(search_time=-1)
# Out:
# Elasped time: 0.0 min
# Using costs {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -106.66666666666664}
# Using step: 2
# <ipython-input-12-2cae7f8adfd9>:1: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   volume_based_config = maxmind.configure_volume_equals_baseline(search_time=-1)
# data available: 14628772
# data length: 14628772
# Checking whether there is an H2O instance running at http://3.230.115.163:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         4 hours 11 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.0.2
# H2O_cluster_version_age:    8 days
# H2O_cluster_name:           root
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    45.23 Gb
# H2O_cluster_total_cores:    36
# H2O_cluster_allowed_cores:  36
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://3.230.115.163:54321
# H2O_connection_proxy:       null
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  ------------------------------------------------------------------
# Date: 2020-03-31 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# xgboost prediction progress: |████████████████████████████████████████████| 100%
# optimum_threshold: 0.36
# Could not find exact threshold 0.36; using closest threshold found 0.362914387697793.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.362914387697793:
#                   0        1   Error                  Rate
# 0      0  1899146.0   4492.0  0.0024    (4492.0/1903638.0)
# 1      1    52353.0   5896.0  0.8988     (52353.0/58249.0)
# 2  Total  1951499.0  10388.0   0.029   (56845.0/1961887.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# xgboost prediction progress: |████████████████████████████████████████████| 100%
# The modified system has an impact of -415452.27
# new_approach: -19035576.73333336  -  today: -18620124.46666668
# Date: 2020-06-29 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.26
# Could not find exact threshold 0.26; using closest threshold found 0.26020101915799587.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.26020101915799587:
#                0     1   Error              Rate
# 0      0  9606.0  40.0  0.0041     (40.0/9646.0)
# 1      1   352.0  45.0  0.8866     (352.0/397.0)
# 2  Total  9958.0  85.0   0.039   (392.0/10043.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# The modified system has an impact of -645071.37
# new_approach: -20003403.600000005  -  today: -19358332.23333332
# Date: 2020-09-27 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.31
# Could not find exact threshold 0.31; using closest threshold found 0.31266113276261254.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.31266113276261254:
#                0     1   Error              Rate
# 0      0  9615.0  26.0  0.0027     (26.0/9641.0)
# 1      1   370.0  30.0   0.925     (370.0/400.0)
# 2  Total  9985.0  56.0  0.0394   (396.0/10041.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# The modified system has an impact of 0.0
# new_approach: 0.0  -  today: 0.0
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.34
# Could not find exact threshold 0.34; using closest threshold found 0.34511867262782614.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.34511867262782614:
#                0     1   Error              Rate
# 0      0  9561.0  26.0  0.0027     (26.0/9587.0)
# 1      1   406.0  48.0  0.8943     (406.0/454.0)
# 2  Total  9967.0  74.0   0.043   (432.0/10041.0)
# <class 'str'>
# /Users/kerrirapes/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/models/StackedEnsemble_BestOfFamily_AutoML_20201125_164334 /Users/kerrirapes/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/models/StackedEnsemble_BestOfFamily_AutoML_20201125_164334
# evaluated cost function: {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -106.66666666666664}
# vol_diff: The new approach saved 4153 tickets
# cost_diff: The new approach had and impact of -1060523.633333385
# cost_saving: 1060523.6333334
#
# Elasped time: 284117.09 min
# Using costs {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -142.22222222222217}
# Using step: 3
# <ipython-input-12-2cae7f8adfd9>:1: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   volume_based_config = maxmind.configure_volume_equals_baseline(search_time=-1)
# data available: 14628772
# data length: 14628772
# Checking whether there is an H2O instance running at http://3.230.115.163:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         5 hours 30 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.0.2
# H2O_cluster_version_age:    8 days
# H2O_cluster_name:           root
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    44.43 Gb
# H2O_cluster_total_cores:    36
# H2O_cluster_allowed_cores:  36
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://3.230.115.163:54321
# H2O_connection_proxy:       null
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  ------------------------------------------------------------------
# Date: 2020-03-31 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# xgboost prediction progress: |████████████████████████████████████████████| 100%
# optimum_threshold: 0.28
# Could not find exact threshold 0.28; using closest threshold found 0.2798553901638015.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.2798553901638015:
#                   0        1   Error                  Rate
# 0      0  1892913.0  10725.0  0.0056   (10725.0/1903638.0)
# 1      1    49183.0   9066.0  0.8444     (49183.0/58249.0)
# 2  Total  1942096.0  19791.0  0.0305   (59908.0/1961887.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# xgboost prediction progress: |████████████████████████████████████████████| 100%
# The modified system has an impact of -620927.82
# new_approach: -25538261.17777777  -  today: -24917333.355555527
# Date: 2020-06-29 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.23
# Could not find exact threshold 0.23; using closest threshold found 0.23016878616900385.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.23016878616900385:
#                0      1   Error              Rate
# 0      0  9594.0   52.0  0.0054     (52.0/9646.0)
# 1      1   348.0   49.0  0.8766     (348.0/397.0)
# 2  Total  9942.0  101.0  0.0398   (400.0/10043.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# The modified system has an impact of -851345.18
# new_approach: -26789161.85555554  -  today: -25937816.67777776
# Date: 2020-09-27 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.23
# Could not find exact threshold 0.23; using closest threshold found 0.22808866682579845.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.22808866682579845:
#                0     1   Error              Rate
# 0      0  9612.0  29.0   0.003     (29.0/9641.0)
# 1      1   368.0  32.0    0.92     (368.0/400.0)
# 2  Total  9980.0  61.0  0.0395   (397.0/10041.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# The modified system has an impact of 0.0
# new_approach: 0.0  -  today: 0.0
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# optimum_threshold: 0.25
# Could not find exact threshold 0.25; using closest threshold found 0.24963868494210292.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.24963868494210292:
#                0     1   Error              Rate
# 0      0  9610.0  31.0  0.0032     (31.0/9641.0)
# 1      1   367.0  33.0  0.9175     (367.0/400.0)
# 2  Total  9977.0  64.0  0.0396   (398.0/10041.0)
# <class 'str'>
# /Users/kerrirapes/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/models/StackedEnsemble_AllModels_AutoML_20201125_180428 /Users/kerrirapes/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/models/StackedEnsemble_AllModels_AutoML_20201125_180428
# evaluated cost function: {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -142.22222222222217}
# vol_diff: The new approach saved 1347 tickets
# cost_diff: The new approach had and impact of -1472272.9999999627
# cost_saving: 1472272.9999999925
#
# Elasped time: 583360.48 min
# Using costs {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -189.62962962962956}
# Using step: 3
# <ipython-input-12-2cae7f8adfd9>:1: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   volume_based_config = maxmind.configure_volume_equals_baseline(search_time=-1)
# data available: 14628772
# data length: 14628772
# Checking whether there is an H2O instance running at http://3.230.115.163:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         6 hours 53 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.0.2
# H2O_cluster_version_age:    8 days
# H2O_cluster_name:           root
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    44.12 Gb
# H2O_cluster_total_cores:    36
# H2O_cluster_allowed_cores:  36
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://3.230.115.163:54321
# H2O_connection_proxy:       null
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  ------------------------------------------------------------------
# Date: 2020-03-31 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training AutoML
# AutoML progress: |████████████████████████████████████████████████████████| 100%
# xgboost prediction progress: |████████████████████████████████████████████| 100%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-2cae7f8adfd9> in <module>
# ----> 1 volume_based_config = maxmind.configure_volume_equals_baseline(search_time=-1)
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/MaxmindIp.py in configure_volume_equals_baseline(self, search_time, sample_size, model_type, cost_matrix_loss_metric)
#     396                 self._config['costs']['cost_fn'] = self._config['costs']['cost_fn'] * (1 + 1 / step)
#     397             print(f"Using costs {self._config['costs']} \n"
# --> 398                   f"Using step: {step}")
#     399
#     400             data = self.train(reset_lookback=False,
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/MaxmindIp.py in train(self, reset_lookback, reset_step, sample_size, evaluate, model_type, cost_matrix_loss_metric, search_time)
#     214                                           port=self.port
#     215                                           )
# --> 216
#     217         if evaluate:
#     218             self._data = todays_update.evaluate(data)
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/TrainingModel.py in evaluate(self, data)
#     421         data['today_result_cost'] = data[f"today_result_cost_{self._lookback}_{self._step}"]
#     422         self._data = data
# --> 423         return data
#     424
#     425     def calibrate_lookback(self, data: pd.DataFrame, step: int) -> int:
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/TrainingModel.py in calibration(self, data, parm)
#     355             df = build_weights(data[data['when_created'] < date].copy(), lookback=parm['lookback'])
#     356             df = df[df['weight'] != 0]
# --> 357             model, threshold = self.calibrate_thresholds(df, model_type=self.model_type,
#     358                                                          cost_matrix_loss_metric=self.cost_matrix_loss_metric)
#     359
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/TrainingModel.py in calibrate_thresholds(self, df, model_type, cost_matrix_loss_metric)
#     321                                       'weight')
#     322
# --> 323         threshold = self.optimum_threshold(train, model)
#     324         print(model.confusion_matrix(thresholds=threshold))
#     325         return model, threshold
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/TrainingModel.py in optimum_threshold(self, hf, model)
#     148             df['prediction'] = predict(df, t, 1, 'model_score')
#     149             df = reconcile(df, 'prediction', 'fraud', f"CM_{t}")
# --> 150             t_cost, df = outcome(df, self.inverse_costs, f"CM_{t}", f"costs_{t}")
#     151             matrix[str(model.model_id)]['x'].append(t)
#     152             matrix[str(model.model_id)]['y'].append(t_cost)
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/utils.py in outcome(df, costs, col, name)
#      79     df[name] = np.where(df[col] == 'tp', costs['cost_tp'] * df['weight'], df[name])
#      80     df[name] = np.where(df[col] == 'tn', costs['cost_tn'] * df['weight'], df[name])
# ---> 81     df[name] = np.where(df[col] == 'fn', costs['cost_fn'] * df['weight'], df[name])
#      82
#      83     return float(df[name].sum()), df
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     237
#     238     elif is_object_dtype(lvalues.dtype):
# --> 239         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     240
#     241     else:
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# KeyboardInterrupt:

# %%
trial = permutations['trial_1']
print(trial)

maxmind = MaxmindIp(ip=ip,
                    username='h2o',
                    password=password,
                    port=54321)
maxmind.config['costs'] = {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -142.22222222222217}
maxmind.config['step'] = 90
data = maxmind.train(reset_lookback=False,
                     reset_step=False,
                     sample_size=None,
                     model_type=trial['model_type'],
                     cost_matrix_loss_metric=trial['cost_matrix_loss_metric'],
                     search_time=SEARCH_TIME,
                     evaluate=True)

# %%
maxmind.plot_vs_baseline()
# Out:
# Cost Baseline: -50855150.033333324    Cost New Approach: -52327423.03333332
# Impact: -1472272.9999999925
# <AxesSubplot:xlabel='grp', ylabel='today_result_cost'>

# %%
maxmind.stats_volume_vs_baseline()
# Out:
# Total Volume sent to UPS (TP + FP):
# 	 Baseline: 13877  New Approach: 12530
# The new approach has a decrease of 1347 tickets
# This represents a decrease of 9.706708942855084 percent

# %%
maxmind.stats_fp_vs_baseline()
# Out:
# Total Fraud Cases Detected (FP):
# 	 Baseline: 5466  New Approach: 11796
# The new approach has an increase of 6330 False Positives
# This represents change of -115.80680570801319 percent

# %%
maxmind.stats_tp_vs_baseline()
# Out:
# Total Fraud Cases Detected (TP):
# 	 Baseline: 8411  New Approach: 734
# The new approach has a decrease of 7677 True Positives
# This represents change of 91.27333254072049 percent

# %%
trial = permutations['trial_3']
print(trial)

maxmind = MaxmindIp(ip=ip,
                    username='h2o',
                    password=password,
                    port=54321)
maxmind.config['step'] = 90
maxmind.config['costs'] = {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -142.22222222222217}
maxmind.config['cutoff'] = 85
data = maxmind.train(reset_lookback=False,
                     reset_step=False,
                     sample_size=None,
                     model_type=trial['model_type'],
                     cost_matrix_loss_metric=trial['cost_matrix_loss_metric'],
                     search_time=SEARCH_TIME,
                     evaluate=True)
# Out:
# {'model_type': 'GradientBoosting', 'cost_matrix_loss_metric': True}
# data available: 14628772
# data length: 14628772
# Checking whether there is an H2O instance running at http://3.230.115.163:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         7 hours 34 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.0.2
# H2O_cluster_version_age:    8 days
# H2O_cluster_name:           root
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    43.36 Gb
# H2O_cluster_total_cores:    36
# H2O_cluster_allowed_cores:  36
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://3.230.115.163:54321
# H2O_connection_proxy:       null
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.5 final
# --------------------------  ------------------------------------------------------------------
# Date: 2020-03-31 00:00:00       Lookback: 270   Step: 90
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# INFO:root:Training Gradient Boosting with cost_matrix_loss_metric
# file written
# INFO:src.maxmind_ip.TrainingModel:Searching Hyper Parameter Space:
#  {'learn_rate': [0.01, 0.1], 'max_depth': [3, 5, 9], 'sample_rate': [0.8, 1.0], 'col_sample_rate': [0.2, 0.5, 1.0]}
# gbm Grid Build progress: |████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# optimum_threshold: 0.29
# Could not find exact threshold 0.29; using closest threshold found 0.2893740572113656.
#
# Confusion Matrix (Act/Pred) @ threshold = 0.2893740572113656:
#                   0        1   Error                  Rate
# 0      0  1891278.0  12361.0  0.0065   (12361.0/1903639.0)
# 1      1    47546.0  10703.0  0.8163     (47546.0/58249.0)
# 2  Total  1938824.0  23064.0  0.0305   (59907.0/1961888.0)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# The modified system has an impact of -620927.82
# new_approach: -25538261.17777777  -  today: -24917333.355555527
# ---------------------------------------------------------------------------
# H2OServerError                            Traceback (most recent call last)
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/h2o.py in remove(x, cascade)
#    1212             try:
# -> 1213                 rapids("(rm {})".format(xi))
#    1214             except:
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/h2o.py in rapids(expr)
#    1255     assert_is_type(expr, str)
# -> 1256     return ExprNode.rapids(expr)
#    1257
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/expr.py in rapids(expr)
#     257         """
# --> 258         return h2o.api("POST /99/Rapids", data={"ast": expr, "session_id": h2o.connection().session_id})
#     259
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/h2o.py in api(endpoint, data, json, filename, save_to)
#     106     _check_connection()
# --> 107     return h2oconn.request(endpoint, data=data, json=json, filename=filename, save_to=save_to)
#     108
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/backend/connection.py in request(self, endpoint, data, json, filename, save_to)
#     477             self._log_end_transaction(start_time, resp)
# --> 478             return self._process_response(resp, save_to)
#     479
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/backend/connection.py in _process_response(response, save_to)
#     828         # did not provide the correct status code.
# --> 829         raise H2OServerError("HTTP %d %s:\n%r" % (status_code, response.reason, data))
#     830
#
# H2OServerError: HTTP 500 Server Error:
# Server error java.lang.RuntimeException:
#   Error: multiple descriptors?: [B$Icer
#   Request: None
#
#
# During handling of the above exception, another exception occurred:
#
# H2OServerError                            Traceback (most recent call last)
# <ipython-input-18-c717965ed58c> in <module>
#       9 maxmind.config['costs'] = {'cost_tp': 0, 'cost_fp': -60, 'cost_tn': 0.1, 'cost_fn': -142.22222222222217}
#      10 maxmind.config['cutoff'] = 85
# ---> 11 data = maxmind.train(reset_lookback=False,
#      12                      reset_step=False,
#      13                      sample_size=None,
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/MaxmindIp.py in train(self, reset_lookback, reset_step, sample_size, evaluate, model_type, cost_matrix_loss_metric, search_time)
#     214                                           port=self.port
#     215                                           )
# --> 216
#     217         if evaluate:
#     218             self._data = todays_update.evaluate(data)
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/TrainingModel.py in evaluate(self, data)
#     421         data['today_result_cost'] = data[f"today_result_cost_{self._lookback}_{self._step}"]
#     422         self._data = data
# --> 423         return data
#     424
#     425     def calibrate_lookback(self, data: pd.DataFrame, step: int) -> int:
#
# ~/Documents/Projects/sendwave/analysis/data_interpretation_modules/src/maxmind_ip/TrainingModel.py in calibration(self, data, parm)
#     385             dates.append(date)
#     386
# --> 387         return impacts, dates
#     388
#     389     @staticmethod
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/h2o.py in remove(x, cascade)
#    1213                 rapids("(rm {})".format(xi))
#    1214             except:
# -> 1215                 api("DELETE /3/DKV/%s" % xi, data=dict(cascade=cascade))
#    1216
#    1217
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/h2o.py in api(endpoint, data, json, filename, save_to)
#     105     # type checks are performed in H2OConnection class
#     106     _check_connection()
# --> 107     return h2oconn.request(endpoint, data=data, json=json, filename=filename, save_to=save_to)
#     108
#     109
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/backend/connection.py in request(self, endpoint, data, json, filename, save_to)
#     476                 save_to = save_to(resp)
#     477             self._log_end_transaction(start_time, resp)
# --> 478             return self._process_response(resp, save_to)
#     479
#     480         except (requests.exceptions.ConnectionError, requests.exceptions.HTTPError) as e:
#
# ~/Documents/Projects/sendwave/analysis/email_maxmind/emaxmind/lib/python3.8/site-packages/h2o/backend/connection.py in _process_response(response, save_to)
#     827         # Note that it is possible to receive valid H2OErrorV3 object in this case, however it merely means the server
#     828         # did not provide the correct status code.
# --> 829         raise H2OServerError("HTTP %d %s:\n%r" % (status_code, response.reason, data))
#     830
#     831
#
# H2OServerError: HTTP 500 Server Error:
# Server error java.lang.RuntimeException:
#   Error: multiple descriptors?: [B$Icer
#   Request: None
